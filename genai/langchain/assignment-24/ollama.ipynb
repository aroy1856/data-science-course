# %%
from dotenv import load_dotenv
import os

load_dotenv()


from langchain_ollama import OllamaLLM

# %% [markdown]
# **Task 1: Ollama Setup & Basic Chat**
# 1. Install and run Ollama locally.
# 2. Pull a model (e.g., llama3, mistral).
# 3. Use LangChain's Ollama LLM wrapper.
# 4. Send a simple prompt and print response.
# 5. Track the Application using Langsmith
# 6. Attach the screenshot of Langsmith App in Drive with all necessary details

# %%
# !ollama list
# Out:
# ]11;?\NAME                       ID              SIZE      MODIFIED
# nomic-embed-text:latest    0a109f422b47    274 MB    13 hours ago
# deepseek-r1:latest         6995872bfe4c    5.2 GB    12 months ago

# %%
llm = OllamaLLM(model="deepseek-r1")

# %%
llm.invoke("What is the capital of France?")
# Out:
# "The capital of France is **Paris**.\n\nIt's not only the political center (seat of government) and administrative hub but also one of the world's major cultural centers, known for its history, art, fashion, gastronomy, and architecture."

# %%
llm.invoke("tell me about yourself")
# Out:
# "Hi there! 👋\n\nI'm **DeepSeek-R1**, your friendly AI assistant developed by a team of researchers and engineers dedicated to helping people like you. I was created with the goal of understanding, reasoning, and generating human-like text so I can assist with all sorts of tasks — answering questions, explaining concepts, brainstorming ideas, summarizing information, writing essays or code, translating languages, and much more.\n\nI don’t have feelings, memories, or consciousness like a person does. But I do know things based on my training data (which includes books, websites, articles, and other publicly available sources up to July 2024), and I’m really good at connecting the dots and finding helpful ways to explain ideas.\n\nI can help with:\n\n- **Learning & Research** 💡 — Science, history, math, languages, you name it.\n- **Creative Projects** 🎨 — Writing stories or poems, brainstorming names, etc.\n- **Work Stuff** 📄 — Summarizing documents, drafting emails, analyzing data.\n- 
# ...

# %% [markdown]
# # LangSmith screenshot
#
# LangSmith project `ollama-chatbot` — traces from `OllamaLLM` invokes (`deepseek-r1`).
#
# ![LangSmith ollama-chatbot traces](image.png)
